# %% [markdown]
# ## Open data with pandas

# %%
import pandas as pd

df = pd.read_json('corpus_imdb.json')

with pd.option_context('display.max_colwidth', 100):
    display(df.head(20))
# Out:
#     id                                                title  \
# 0    0                                           Les Évadés
# 1    1                                           Le Parrain
# 2    2                  The Dark Knight : Le Chevalier noir
# 3    3                                Le Parrain, 2ᵉ partie
# 4    4                                  12 Hommes en colère
# 5    5                                La Liste de Schindler
# 6    6           Le Seigneur des anneaux : Le Retour du roi
# 7    7                                         Pulp Fiction
# 8    8  Le Seigneur des anneaux : La Communauté de l'anneau
# 9    9                        Le Bon, la Brute et le Truand
# 10  10                                         Forrest Gump
# 11  11             Le Seigneur des anneaux : Les Deux Tours
# 12  12                                           Fight Club
# 13  13                                            Inception
# 14  14                              L'Empire contre-attaque
# ...

# %% [markdown]
# ## Convert corpus to Dataset

# %%
from datasets import Dataset
ds = Dataset.from_pandas(df)

print(ds)
# Out:
# Dataset({
#     features: ['id', 'title', 'og_title', 'year', 'genres', 'director', 'rating', 'synopsis', 'analysis'],
#     num_rows: 250
# })

# %%
ds[0]
# Out:
# {'id': 0,
#  'title': 'Les Évadés',
#  'og_title': 'The Shawshank Redemption',
#  'year': 1994,
#  'genres': ['Drame'],
#  'director': 'Frank Darabont',
#  'rating': '9,3',
#  'synopsis': "Le banquier Andy Dufresne est arrêté pour avoir tué sa femme et son amant. Après une dure adaptation, il tente d'améliorer les conditions de la prison et de redonner de l'espoir à ses compagnons.",
#  'analysis': [{'tokens': [{'lemma': 'le', 'pos': 'DET', 'text': 'Le'},
#     {'lemma': 'banquier', 'pos': 'NOUN', 'text': 'banquier'},
#     {'lemma': 'Andy', 'pos': 'PROPN', 'text': 'Andy'},
#     {'lemma': 'Dufresne', 'pos': 'PROPN', 'text': 'Dufresne'},
#     {'lemma': 'être', 'pos': 'AUX', 'text': 'est'},
#     {'lemma': 'arrêter', 'pos': 'VERB', 'text': 'arrêté'},
#     {'lemma': 'pour', 'pos': 'ADP', 'text': 'pour'},
#     {'lemma': 'avoir', 'pos': 'AUX', 'text': 'avoir'},
#     {'lemma': 'tuer', 'pos': 'VERB', 'text': 'tué'},
#     {'lemma': 'son', 'pos': 'DET', 'text': 'sa'},
# ...
